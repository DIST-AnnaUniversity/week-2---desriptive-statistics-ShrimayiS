# %%
import pandas as pd

# %%
df = pd.read_csv("./wpi_monthly_data.csv")

# %%
df.head()
# Out:
#                           COMM_NAME   COMM_CODE    COMM_WT  INDX042011  \
# 0                   ALL COMMODITIES  1000000000  100.00000        97.2
# 1             I    PRIMARY ARTICLES  1100000000   22.61756        95.6
# 2               (A).  FOOD ARTICLES  1101000000   15.25585        94.5
# 3  a.  FOOD GRAINS (CEREALS+PULSES)  1101010000    3.46238        97.6
# 4                       a1. CEREALS  1101010100    2.82378        98.5
#
#    INDX052011  INDX062011  INDX072011  INDX082011  INDX092011  INDX102011  \
# 0        97.8        98.3        98.7        99.3       100.2       100.7
# 1        95.7        97.6        98.6       100.4       102.1       102.4
# 2        95.5        98.0        99.6       101.5       103.6       104.7
# 3        98.7        98.8        99.6       100.2       101.1       100.9
# 4        99.7        99.7       100.5       100.8       100.7        99.8
#
#    ...  INDX062022  INDX072022  INDX082022  INDX092022  INDX102022  \
# 0  ...       154.0       153.8       153.1       152.1         NaN
# 1  ...       182.4       177.5       178.6       176.2         NaN
# 2  ...       183.6       178.9       181.7       182.2         NaN
# 3  ...       170.7       172.6       177.0       178.5         NaN
# 4  ...       170.3       172.1       176.6       178.5         NaN
#
#    INDX112022  INDX122022  INDX012023  INDX022023  INDX032023
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 147 columns]

# %%
cols = df.columns.tolist()

# %%
cols.remove('COMM_NAME')
cols.remove('COMM_CODE')
cols.remove('COMM_WT')

# %%
for c in cols:
    try:
        print(f"Mean of {c} is {df[c].mean()}")
        print(f"Median of {c} is {df[c].median()}")
        print(f"Mode of {c} : ")
        print(df[c].mode())
        print("--" * 50)
    except Exception as e:
        pass
# Out:
# Mean of INDX042011 is 98.25702764976947
# Median of INDX042011 is 98.3
# Mode of INDX042011 :
# 0    100.0
# Name: INDX042011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052011 is 98.41109826589592
# Median of INDX052011 is 98.8
# Mode of INDX052011 :
# 0    100.0
# Name: INDX052011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062011 is 98.82771362586614
# Median of INDX062011 is 99.0
# Mode of INDX062011 :
# 0    100.0
# Name: INDX062011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072011 is 99.11028901734117
# Median of INDX072011 is 99.2
# Mode of INDX072011 :
# 0    100.0
# Name: INDX072011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082011 is 99.65706018518527
# Median of INDX082011 is 99.6
# Mode of INDX082011 :
# 0    100.0
# Name: INDX082011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092011 is 100.2523148148148
# Median of INDX092011 is 99.9
# Mode of INDX092011 :
# 0    100.0
# Name: INDX092011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102011 is 100.62416184971106
# Median of INDX102011 is 100.1
# Mode of INDX102011 :
# 0    100.0
# Name: INDX102011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112011 is 100.64613610149935
# Median of INDX112011 is 100.3
# Mode of INDX112011 :
# 0    100.0
# Name: INDX112011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122011 is 100.60196078431375
# Median of INDX122011 is 100.7
# Mode of INDX122011 :
# 0    100.0
# Name: INDX122011, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012012 is 101.36412918108421
# Median of INDX012012 is 101.1
# Mode of INDX012012 :
# 0    100.0
# Name: INDX012012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022012 is 101.89296424452138
# Median of INDX022012 is 101.2
# Mode of INDX022012 :
# 0    100.0
# Name: INDX022012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032012 is 102.87197231833915
# Median of INDX032012 is 101.7
# Mode of INDX032012 :
# 0    100.0
# Name: INDX032012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042012 is 103.97223502304146
# Median of INDX042012 is 103.15
# Mode of INDX042012 :
# 0    100.0
# Name: INDX042012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052012 is 104.16705202312137
# Median of INDX052012 is 103.7
# Mode of INDX052012 :
# 0    100.0
# Name: INDX052012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062012 is 104.91235565819862
# Median of INDX062012 is 104.1
# Mode of INDX062012 :
# 0    100.0
# Name: INDX062012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072012 is 105.99537572254341
# Median of INDX072012 is 104.7
# Mode of INDX072012 :
# 0    101.7
# Name: INDX072012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082012 is 106.27152777777772
# Median of INDX082012 is 105.0
# Mode of INDX082012 :
# 0    105.6
# Name: INDX082012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092012 is 106.48784722222214
# Median of INDX092012 is 105.3
# Mode of INDX092012 :
# 0    100.0
# Name: INDX092012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102012 is 106.55907514450877
# Median of INDX102012 is 105.4
# Mode of INDX102012 :
# 0    100.0
# Name: INDX102012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112012 is 106.67474048442915
# Median of INDX112012 is 105.4
# Mode of INDX112012 :
# 0    100.0
# Name: INDX112012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122012 is 106.88073817762397
# Median of INDX122012 is 105.5
# Mode of INDX122012 :
# 0    100.0
# Name: INDX122012, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012013 is 107.77981545559417
# Median of INDX012013 is 105.8
# Mode of INDX012013 :
# 0    104.6
# Name: INDX012013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022013 is 107.92895040369088
# Median of INDX022013 is 106.0
# Mode of INDX022013 :
# 0    102.5
# 1    105.9
# Name: INDX022013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032013 is 108.06885813148789
# Median of INDX032013 is 106.4
# Mode of INDX032013 :
# 0    103.4
# 1    107.6
# Name: INDX032013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042013 is 108.75887096774191
# Median of INDX042013 is 107.3
# Mode of INDX042013 :
# 0    106.6
# Name: INDX042013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052013 is 108.98404624277475
# Median of INDX052013 is 106.9
# Mode of INDX052013 :
# 0    103.7
# Name: INDX052013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062013 is 109.92344110854505
# Median of INDX062013 is 107.7
# Mode of INDX062013 :
# 0    101.5
# 1    104.7
# Name: INDX062013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072013 is 110.61803468208109
# Median of INDX072013 is 108.2
# Mode of INDX072013 :
# 0    109.7
# Name: INDX072013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082013 is 112.00173611111119
# Median of INDX082013 is 109.1
# Mode of INDX082013 :
# 0    106.6
# Name: INDX082013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092013 is 112.8582175925926
# Median of INDX092013 is 110.1
# Mode of INDX092013 :
# 0    110.1
# Name: INDX092013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102013 is 113.6164161849713
# Median of INDX102013 is 110.1
# Mode of INDX102013 :
# 0    105.6
# Name: INDX102013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112013 is 113.79538638985004
# Median of INDX112013 is 110.5
# Mode of INDX112013 :
# 0    103.1
# 1    112.4
# Name: INDX112013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122013 is 113.07416378316043
# Median of INDX122013 is 110.5
# Mode of INDX122013 :
# 0    106.6
# Name: INDX122013, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012014 is 113.13760092272203
# Median of INDX012014 is 110.7
# Mode of INDX012014 :
# 0    105.5
# 1    105.8
# Name: INDX012014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022014 is 113.182122260669
# Median of INDX022014 is 111.3
# Mode of INDX022014 :
# 0    106.2
# 1    111.6
# Name: INDX022014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032014 is 113.5794694348328
# Median of INDX032014 is 111.7
# Mode of INDX032014 :
# 0    106.3
# 1    107.4
# 2    111.7
# Name: INDX032014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042014 is 114.39527649769569
# Median of INDX042014 is 112.35
# Mode of INDX042014 :
# 0    106.0
# Name: INDX042014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052014 is 114.85653179190734
# Median of INDX052014 is 112.8
# Mode of INDX052014 :
# 0    113.7
# Name: INDX052014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062014 is 115.55334872979209
# Median of INDX062014 is 113.2
# Mode of INDX062014 :
# 0    112.4
# Name: INDX062014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072014 is 116.49179190751433
# Median of INDX072014 is 113.5
# Mode of INDX072014 :
# 0    102.7
# 1    125.2
# Name: INDX072014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082014 is 116.92766203703687
# Median of INDX082014 is 114.05
# Mode of INDX082014 :
# 0    102.8
# 1    108.4
# 2    110.5
# 3    114.0
# 4    114.8
# Name: INDX082014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092014 is 116.81770833333336
# Median of INDX092014 is 114.2
# Mode of INDX092014 :
# 0    114.9
# 1    117.2
# Name: INDX092014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102014 is 116.50924855491321
# Median of INDX102014 is 114.1
# Mode of INDX102014 :
# 0    112.6
# 1    117.4
# Name: INDX102014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112014 is 116.0715109573241
# Median of INDX112014 is 113.3
# Mode of INDX112014 :
# 0    111.1
# 1    114.5
# Name: INDX112014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122014 is 115.36113033448663
# Median of INDX122014 is 113.1
# Mode of INDX122014 :
# 0    107.6
# 1    110.7
# 2    113.3
# 3    114.8
# Name: INDX122014, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012015 is 115.2064590542096
# Median of INDX012015 is 112.7
# Mode of INDX012015 :
# 0    122.9
# Name: INDX012015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022015 is 114.38581314878888
# Median of INDX022015 is 112.2
# Mode of INDX022015 :
# 0    109.6
# Name: INDX022015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032015 is 114.4175317185699
# Median of INDX032015 is 112.7
# Mode of INDX032015 :
# 0    113.8
# 1    114.4
# 2    115.8
# 3    120.1
# Name: INDX032015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042015 is 114.3502304147467
# Median of INDX042015 is 112.45
# Mode of INDX042015 :
# 0    108.0
# 1    111.4
# 2    113.3
# Name: INDX042015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052015 is 115.00728323699421
# Median of INDX052015 is 112.9
# Mode of INDX052015 :
# 0    110.9
# 1    111.9
# Name: INDX052015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062015 is 115.59237875288687
# Median of INDX062015 is 112.95
# Mode of INDX062015 :
# 0    109.8
# Name: INDX062015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072015 is 115.48728323699429
# Median of INDX072015 is 112.9
# Mode of INDX072015 :
# 0    108.5
# 1    109.0
# 2    120.3
# Name: INDX072015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082015 is 115.45057870370367
# Median of INDX082015 is 112.6
# Mode of INDX082015 :
# 0     98.9
# 1    105.4
# 2    109.6
# 3    110.0
# Name: INDX082015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092015 is 115.45520833333323
# Median of INDX092015 is 112.65
# Mode of INDX092015 :
# 0    118.4
# Name: INDX092015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102015 is 115.58531791907508
# Median of INDX102015 is 112.6
# Mode of INDX102015 :
# 0    110.1
# Name: INDX102015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112015 is 115.55732410611299
# Median of INDX112015 is 112.7
# Mode of INDX112015 :
# 0    104.2
# 1    119.9
# Name: INDX112015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122015 is 115.49953863898494
# Median of INDX122015 is 112.9
# Mode of INDX122015 :
# 0    115.4
# 1    121.8
# Name: INDX122015, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012016 is 114.81983852364479
# Median of INDX012016 is 112.8
# Mode of INDX012016 :
# 0    123.0
# Name: INDX012016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022016 is 114.18777393310268
# Median of INDX022016 is 112.4
# Mode of INDX022016 :
# 0    107.5
# Name: INDX022016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032016 is 114.4619377162629
# Median of INDX032016 is 112.6
# Mode of INDX032016 :
# 0    114.7
# Name: INDX032016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042016 is 115.36313364055304
# Median of INDX042016 is 112.55
# Mode of INDX042016 :
# 0    115.5
# Name: INDX042016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052016 is 116.05005780346826
# Median of INDX052016 is 113.3
# Mode of INDX052016 :
# 0    127.3
# Name: INDX052016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062016 is 117.18441108545038
# Median of INDX062016 is 113.65
# Mode of INDX062016 :
# 0    101.5
# 1    108.0
# 2    120.5
# Name: INDX062016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072016 is 117.3286705202312
# Median of INDX072016 is 113.6
# Mode of INDX072016 :
# 0    106.0
# 1    110.7
# 2    111.8
# 3    113.3
# 4    117.1
# Name: INDX072016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082016 is 117.04456018518523
# Median of INDX082016 is 113.7
# Mode of INDX082016 :
# 0    103.4
# 1    113.1
# Name: INDX082016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092016 is 117.02511574074069
# Median of INDX092016 is 113.4
# Mode of INDX092016 :
# 0    113.6
# Name: INDX092016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102016 is 116.93364161849713
# Median of INDX102016 is 113.5
# Mode of INDX102016 :
# 0    115.0
# Name: INDX102016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112016 is 117.08235294117631
# Median of INDX112016 is 113.6
# Mode of INDX112016 :
# 0    101.4
# Name: INDX112016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122016 is 116.94821222606708
# Median of INDX122016 is 113.6
# Mode of INDX122016 :
# 0    114.8
# Name: INDX122016, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012017 is 117.26412918108424
# Median of INDX012017 is 113.8
# Mode of INDX012017 :
# 0     95.9
# 1    115.0
# Name: INDX012017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022017 is 117.39331026528264
# Median of INDX022017 is 114.4
# Mode of INDX022017 :
# 0    118.9
# Name: INDX022017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032017 is 117.68938869665524
# Median of INDX032017 is 114.7
# Mode of INDX032017 :
# 0    116.5
# Name: INDX032017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042017 is 117.94711981566824
# Median of INDX042017 is 115.0
# Mode of INDX042017 :
# 0    118.2
# Name: INDX042017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052017 is 117.853063583815
# Median of INDX052017 is 114.9
# Mode of INDX052017 :
# 0    119.9
# Name: INDX052017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062017 is 117.91662817551965
# Median of INDX062017 is 114.80000000000001
# Mode of INDX062017 :
# 0    114.3
# 1    117.5
# Name: INDX062017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072017 is 118.54786127167628
# Median of INDX072017 is 115.0
# Mode of INDX072017 :
# 0    115.2
# Name: INDX072017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082017 is 119.13287037037028
# Median of INDX082017 is 114.6
# Mode of INDX082017 :
# 0    101.9
# 1    105.9
# 2    111.1
# Name: INDX082017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092017 is 119.11458333333319
# Median of INDX092017 is 115.55
# Mode of INDX092017 :
# 0    112.5
# 1    116.1
# Name: INDX092017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102017 is 119.65734104046236
# Median of INDX102017 is 115.7
# Mode of INDX102017 :
# 0    107.5
# 1    111.9
# 2    113.2
# 3    118.9
# Name: INDX102017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112017 is 120.06712802768159
# Median of INDX112017 is 115.7
# Mode of INDX112017 :
# 0    102.4
# 1    109.5
# 2    109.8
# 3    112.9
# 4    113.7
# 5    114.0
# Name: INDX112017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122017 is 119.93483275663223
# Median of INDX122017 is 115.4
# Mode of INDX122017 :
# 0    109.3
# 1    112.0
# 2    113.6
# 3    113.8
# Name: INDX122017, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012018 is 119.90599769319492
# Median of INDX012018 is 115.8
# Mode of INDX012018 :
# 0    108.3
# Name: INDX012018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022018 is 119.70991926182224
# Median of INDX022018 is 116.1
# Mode of INDX022018 :
# 0    105.9
# 1    108.6
# Name: INDX022018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032018 is 119.8489042675893
# Median of INDX032018 is 117.0
# Mode of INDX032018 :
# 0    109.7
# 1    109.8
# Name: INDX032018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042018 is 120.44020737327179
# Median of INDX042018 is 117.65
# Mode of INDX042018 :
# 0    111.4
# 1    112.8
# 2    125.4
# Name: INDX042018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052018 is 120.882774566474
# Median of INDX052018 is 118.2
# Mode of INDX052018 :
# 0    118.2
# Name: INDX052018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062018 is 121.48533487297925
# Median of INDX062018 is 118.5
# Mode of INDX062018 :
# 0    123.1
# Name: INDX062018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072018 is 122.12820809248552
# Median of INDX072018 is 119.0
# Mode of INDX072018 :
# 0    112.5
# Name: INDX072018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082018 is 122.34212962962958
# Median of INDX082018 is 119.0
# Mode of INDX082018 :
# 0    109.8
# Name: INDX082018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092018 is 122.8532407407408
# Median of INDX092018 is 119.8
# Mode of INDX092018 :
# 0    123.2
# Name: INDX092018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102018 is 123.83040462427758
# Median of INDX102018 is 120.4
# Mode of INDX102018 :
# 0    121.6
# Name: INDX102018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112018 is 124.31764705882371
# Median of INDX112018 is 120.7
# Mode of INDX112018 :
# 0    113.6
# 1    114.3
# 2    120.0
# 3    128.7
# Name: INDX112018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122018 is 123.41856978085352
# Median of INDX122018 is 120.1
# Mode of INDX122018 :
# 0    112.5
# 1    118.5
# 2    120.1
# Name: INDX122018, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012019 is 123.44452133794691
# Median of INDX012019 is 119.7
# Mode of INDX012019 :
# 0    109.5
# Name: INDX012019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022019 is 123.56608996539796
# Median of INDX022019 is 119.7
# Mode of INDX022019 :
# 0    114.0
# Name: INDX022019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032019 is 123.83056516724344
# Median of INDX032019 is 120.3
# Mode of INDX032019 :
# 0    115.0
# Name: INDX032019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042019 is 124.74976958525335
# Median of INDX042019 is 120.4
# Mode of INDX042019 :
# 0    111.4
# Name: INDX042019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052019 is 125.02173410404625
# Median of INDX052019 is 120.5
# Mode of INDX052019 :
# 0    116.8
# Name: INDX052019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062019 is 125.27863741339483
# Median of INDX062019 is 119.8
# Mode of INDX062019 :
# 0    107.4
# 1    116.4
# 2    119.5
# Name: INDX062019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072019 is 125.64034682080923
# Median of INDX072019 is 119.6
# Mode of INDX072019 :
# 0    117.5
# Name: INDX072019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082019 is 125.82928240740746
# Median of INDX082019 is 119.35
# Mode of INDX082019 :
# 0    125.3
# Name: INDX082019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092019 is 125.5189814814814
# Median of INDX092019 is 119.4
# Mode of INDX092019 :
# 0    113.7
# 1    117.1
# Name: INDX092019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102019 is 126.09676300578036
# Median of INDX102019 is 119.1
# Mode of INDX102019 :
# 0    109.3
# 1    115.3
# Name: INDX102019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112019 is 126.79377162629747
# Median of INDX112019 is 119.2
# Mode of INDX112019 :
# 0    114.7
# 1    116.5
# 2    119.7
# Name: INDX112019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122019 is 127.38500576701267
# Median of INDX122019 is 119.1
# Mode of INDX122019 :
# 0    116.8
# Name: INDX122019, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012020 is 127.07831603229528
# Median of INDX012020 is 119.4
# Mode of INDX012020 :
# 0    116.4
# Name: INDX012020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022020 is 125.86620530565168
# Median of INDX022020 is 119.2
# Mode of INDX022020 :
# 0    120.1
# Name: INDX022020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032020 is 124.51349480968867
# Median of INDX032020 is 119.1
# Mode of INDX032020 :
# 0    120.1
# 1    127.6
# Name: INDX032020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042020 is 124.25668202764979
# Median of INDX042020 is 119.0
# Mode of INDX042020 :
# 0    117.7
# 1    125.0
# 2    127.0
# Name: INDX042020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052020 is 123.41086705202319
# Median of INDX052020 is 119.0
# Mode of INDX052020 :
# 0    104.4
# 1    115.2
# 2    120.1
# 3    128.6
# 4    130.2
# Name: INDX052020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062020 is 124.20669745958435
# Median of INDX062020 is 119.25
# Mode of INDX062020 :
# 0    117.0
# Name: INDX062020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072020 is 124.60589595375725
# Median of INDX072020 is 119.0
# Mode of INDX072020 :
# 0    116.0
# Name: INDX072020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082020 is 125.70775462962963
# Median of INDX082020 is 119.6
# Mode of INDX082020 :
# 0    110.9
# Name: INDX082020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092020 is 126.81319444444432
# Median of INDX092020 is 120.1
# Mode of INDX092020 :
# 0    123.2
# Name: INDX092020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102020 is 127.62208092485542
# Median of INDX102020 is 120.4
# Mode of INDX102020 :
# 0    111.5
# 1    114.2
# 2    120.4
# 3    140.6
# Name: INDX102020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112020 is 128.78119953863913
# Median of INDX112020 is 121.4
# Mode of INDX112020 :
# 0    113.2
# 1    115.6
# 2    131.8
# Name: INDX112020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122020 is 128.66597462514426
# Median of INDX122020 is 122.4
# Mode of INDX122020 :
# 0    119.1
# Name: INDX122020, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012021 is 129.53529411764714
# Median of INDX012021 is 123.9
# Mode of INDX012021 :
# 0    115.6
# 1    130.2
# Name: INDX012021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022021 is 130.48904267589396
# Median of INDX022021 is 125.1
# Mode of INDX022021 :
# 0    118.0
# Name: INDX022021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032021 is 131.73760092272224
# Median of INDX032021 is 127.1
# Mode of INDX032021 :
# 0    120.2
# Name: INDX032021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042021 is 133.7057603686637
# Median of INDX042021 is 128.64999999999998
# Mode of INDX042021 :
# 0    127.5
# Name: INDX042021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052021 is 134.24219653179193
# Median of INDX052021 is 128.8
# Mode of INDX052021 :
# 0    122.4
# Name: INDX052021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062021 is 135.18833718244798
# Median of INDX062021 is 129.35000000000002
# Mode of INDX062021 :
# 0    116.5
# 1    122.8
# 2    127.3
# 3    129.4
# Name: INDX062021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072021 is 136.0589595375722
# Median of INDX072021 is 130.7
# Mode of INDX072021 :
# 0    136.2
# Name: INDX072021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082021 is 136.97986111111112
# Median of INDX082021 is 130.6
# Mode of INDX082021 :
# 0    121.1
# Name: INDX082021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092021 is 138.22754629629628
# Median of INDX092021 is 131.6
# Mode of INDX092021 :
# 0    138.1
# Name: INDX092021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102021 is 140.88913294797695
# Median of INDX102021 is 133.8
# Mode of INDX102021 :
# 0    131.8
# Name: INDX102021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112021 is 143.3479815455594
# Median of INDX112021 is 135.2
# Mode of INDX112021 :
# 0    150.4
# Name: INDX112021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122021 is 144.35409457900818
# Median of INDX122021 is 135.5
# Mode of INDX122021 :
# 0    127.1
# 1    130.9
# Name: INDX122021, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012022 is 144.80472895040373
# Median of INDX012022 is 136.6
# Mode of INDX012022 :
# 0    122.3
# 1    131.3
# 2    137.1
# 3    142.3
# Name: INDX012022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022022 is 145.65524798154547
# Median of INDX022022 is 137.9
# Mode of INDX022022 :
# 0    132.7
# Name: INDX022022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032022 is 147.01095732410604
# Median of INDX032022 is 139.3
# Mode of INDX032022 :
# 0    139.1
# Name: INDX032022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX042022 is 148.81370967741927
# Median of INDX042022 is 141.14999999999998
# Mode of INDX042022 :
# 0    127.5
# 1    137.8
# Name: INDX042022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX052022 is 149.7527167630057
# Median of INDX052022 is 142.1
# Mode of INDX052022 :
# 0    127.4
# 1    134.7
# Name: INDX052022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX062022 is 150.14665127020774
# Median of INDX062022 is 142.14999999999998
# Mode of INDX062022 :
# 0    122.2
# Name: INDX062022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX072022 is 149.76947976878625
# Median of INDX072022 is 141.9
# Mode of INDX072022 :
# 0    130.7
# 1    137.5
# 2    161.9
# Name: INDX072022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX082022 is 149.62986111111118
# Median of INDX082022 is 141.55
# Mode of INDX082022 :
# 0    134.9
# Name: INDX082022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX092022 is 149.35034722222215
# Median of INDX092022 is 141.3
# Mode of INDX092022 :
# 0    134.9
# Name: INDX092022, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Mean of INDX102022 is nan
# Median of INDX102022 is nan
# Mode of INDX102022 :
# Series([], Name: INDX102022, dtype: float64)
# ----------------------------------------------------------------------------------------------------
# Mean of INDX112022 is nan
# Median of INDX112022 is nan
# Mode of INDX112022 :
# Series([], Name: INDX112022, dtype: float64)
# ----------------------------------------------------------------------------------------------------
# Mean of INDX122022 is nan
# Median of INDX122022 is nan
# Mode of INDX122022 :
# Series([], Name: INDX122022, dtype: float64)
# ----------------------------------------------------------------------------------------------------
# Mean of INDX012023 is nan
# Median of INDX012023 is nan
# Mode of INDX012023 :
# Series([], Name: INDX012023, dtype: float64)
# ----------------------------------------------------------------------------------------------------
# Mean of INDX022023 is nan
# Median of INDX022023 is nan
# Mode of INDX022023 :
# Series([], Name: INDX022023, dtype: float64)
# ----------------------------------------------------------------------------------------------------
# Mean of INDX032023 is nan
# Median of INDX032023 is nan
# Mode of INDX032023 :
# Series([], Name: INDX032023, dtype: float64)
# ----------------------------------------------------------------------------------------------------
